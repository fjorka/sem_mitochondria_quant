# %%
# %load_ext autoreload
# %autoreload 2

import os
from tqdm.notebook import tqdm
import dask.array as da
import pandas as pd
import numpy as np
import pickle as pkl
from tifffile import imread
from skimage.color import gray2rgb

from pathlib import Path
from fastai.learner import load_learner

from utils import extract_regionprops, mask_from_df, suppress_by_iou_mitos, compute_iou_array, add_soma_data, label_func

# %%
im_path = '/mnt/d/data_analysis/2025_Birder_mito/88EM87C 25x25_ashlar.ome.tif'
output_dir = '/mnt/d/data_analysis/2025_Birder_mito/C_00_analysis'
prefix_save = '88EM87C_'
mitos_sub_dir = 'mitos_sam'

classifier_path = Path('/mnt/d/data_analysis/2025_Birder_mito/250416_classifier.pkl')

axon_res = 3
mitos_res = 0
row_offset = 0 # used if df was created as a test on a smaller image
col_offset = 0 # used if df was created as a test on a smaller image

# details of selecting mito masks
res_adjust = axon_res - mitos_res

properties = ['area', 'area_convex', 'area_filled', 'euler_number', 'image','bbox',
        'eccentricity', 'solidity', 'centroid', 'major_axis_length', 'minor_axis_length']

min_iou = 0.85
iou_threshold = 0.2 # used for suppressing overlapping mito masks
min_area = 200
max_area = 2000
max_eccentricity = 0.9

# parameters for the classifier
pad = 50

# %% [markdown]
# ## Get an image

# %%
store = imread(im_path, aszarr=True)
im = da.from_zarr(store, mitos_res)
print('Image shape:', im.shape)
# Out:
# Image shape: (22084, 29266)

# %% [markdown]
# ## Get main df

# %%
df_name = f'{prefix_save}axons.pkl'
df_path = os.path.join(output_dir,df_name)
df_cells = pd.read_pickle(df_path)
print('Number of axons:',len(df_cells))
df_cells.head()
# Out:
# Number of axons: 548
#    index   area                          bbox  predicted_iou  \
# 0      1   8317  [740.0, 671.0, 157.0, 118.0]       0.972656
# 1     14    722    [921.0, 953.0, 29.0, 45.0]       0.914062
# 2     54   8935  [744.0, 306.0, 136.0, 134.0]       0.964844
# 3     80   7428   [139.0, 69.0, 134.0, 137.0]       0.976562
# 4     85  10627   [68.0, 197.0, 126.0, 145.0]       0.953125
#
#                point_coords  stability_score                      crop_box  \
# 0  [[771.34375, 699.15625]]         0.961874  [639.0, 639.0, 385.0, 385.0]
# 1  [[939.78125, 963.84375]]         0.943472  [639.0, 639.0, 385.0, 385.0]
# 2  [[867.59375, 346.03125]]         0.964152  [639.0, 213.0, 385.0, 387.0]
# 3   [[157.21875, 84.65625]]         0.971724      [0.0, 0.0, 387.0, 387.0]
# 4   [[84.65625, 253.96875]]         0.972049      [0.0, 0.0, 387.0, 387.0]
#
#    tile_row_start  tile_row_end  tile_col_start  ...  inside_centroid-1  \
# 0               0          1024               0  ...              812.0
# 1               0          1024               0  ...              934.0
# 2               0          1024               0  ...              814.0
# 3               0          1024               0  ...              205.0
# 4               0          1024               0  ...              139.0
#
#    inside_area  inside_eccentricity  inside_major_axis_length  \
# 0       5262.0             0.780537                106.290709
# 1        282.0             0.929873                 32.778532
# 2       4639.0             0.504062                 82.751126
# 3       6586.0             0.501551                 99.604531
# 4       2564.0             0.644323                 65.395412
#
#    inside_minor_axis_length  inside_bbox-0 inside_bbox-1  inside_bbox-2  \
# 0                 66.443329          694.0         766.0          767.0
# 1                 12.058577          961.0         928.0          992.0
# 2                 71.469438          330.0         775.0          409.0
# 3                 86.170657           89.0         159.0          187.0
# 4                 50.011351          244.0         112.0          302.0
#
#    inside_bbox-3  inside_label
# 0          873.0             1
# 1          943.0             2
# 2          854.0             3
# 3          250.0             4
# 4          169.0             5
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Get SAM masks

# %%
masks_dir = os.path.join(output_dir,mitos_sub_dir)
file_list = [x for x in os.listdir(masks_dir) if x.endswith('.pkl')]   
print(f'Found {len(file_list)} mito masks in {masks_dir}')
# Out:
# Found 546 mito masks in /mnt/d/data_analysis/2025_Birder_mito/C_00_analysis/mitos_sam

# %%
df_list = []

for file_name in tqdm(file_list):

    print(f'Processing {file_name}')
    
    # load suggested mito masks
    file_path = os.path.join(masks_dir, file_name)
    masks_org = pkl.load(open(file_path, 'rb'))

    # get info about the cell
    cell_ind = int(file_name.split('_')[1])
    row = df_cells.loc[df_cells['label'] == cell_ind]
    inside_mask = row['inside_image'].values[0]

    # discard mitos not inside axons
    masks_sel = [x for x in masks_org if inside_mask[int(x['point_coords'][0][1]/2**res_adjust), int(x['point_coords'][0][0]/2**res_adjust)]]

    df = pd.DataFrame(masks_sel)
    if len(df) == 0:
        print('No masks found')
        continue

    # get mitos data
    df = df[((df['area'] > min_area) & (df['area'] < max_area) & (df['predicted_iou'] > min_iou))]
    print(f'Number of masks: {len(df)}')

    props_list = [] 
    for ind, row_mito in df.iterrows():
        props = extract_regionprops(row_mito,properties,small_size = min_area)
        # keep origin of the data
        props['origin'] = ind
        props_list.append(props)

    if len(props_list) == 0:
        print('No masks found')
        continue
    
    props_all = pd.concat(props_list, ignore_index=True)

    props_all.columns = [ f'mito_{col}' if col == 'area' else col for col in props_all.columns]

    # Concatenate with the original DataFrame
    df['origin'] = df.index
    df_all = pd.merge(df, props_all,left_on = 'origin', right_on= 'origin', how = 'right').reset_index()

    # drop objects by measured categories
    df_all = df_all[(df_all['eccentricity'] < max_eccentricity)]

    print(f'Number of separate objects: {len(df_all)}')

    # suppress by iou
    df_all = df_all.reset_index(drop=True)
    df_all = suppress_by_iou_mitos(df_all, iou_threshold=iou_threshold)
    df_all = df_all.loc[df_all.keep==1,:]
    print(f'Number of self standing objects: {len(df_all)}')

    # shift into the main coordinate system

    row_start = (int(row['inside_bbox-0'].iloc[0]) + row_offset)*2**res_adjust
    row_end = (int(row['inside_bbox-2'].iloc[0]) + row_offset)*2**res_adjust
    col_start = (int(row['inside_bbox-1'].iloc[0]) + col_offset)*2**res_adjust
    col_end = (int(row['inside_bbox-3'].iloc[0]) + col_offset)*2**res_adjust

    df_all['bbox-0'] = df_all['bbox-0'] + row_start
    df_all['bbox-2'] = df_all['bbox-2'] + row_start
    df_all['bbox-1'] = df_all['bbox-1'] + col_start
    df_all['bbox-3'] = df_all['bbox-3'] + col_start
    df_all['centroid-0'] = df_all['centroid-0'] + row_start
    df_all['centroid-1'] = df_all['centroid-1'] + col_start

    df_all['cell_label'] = cell_ind

    # drop segmentation in the local coord system
    df_all.drop(columns=['segmentation'], inplace=True)
    # drop area of the orignal segmented region
    df_all.drop(columns=['area'], inplace=True)

    df_list.append(df_all)

df_mitos = pd.concat(df_list, ignore_index=True)
df_mitos['label'] = df_mitos.index + 1
# Out:
#   0%|          | 0/546 [00:00<?, ?it/s]
# Processing 88EM87C_000003_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000004_mito.pkl
# Number of masks: 17
# Number of separate objects: 12
# Number of self standing objects: 10
# Processing 88EM87C_000005_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 9
# Processing 88EM87C_000006_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000007_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000008_mito.pkl
# Number of masks: 32
# Number of separate objects: 28
# Number of self standing objects: 22
# Processing 88EM87C_000009_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000010_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000011_mito.pkl
# Number of masks: 22
# Number of separate objects: 19
# Number of self standing objects: 17
# Processing 88EM87C_000012_mito.pkl
# Number of masks: 32
# Number of separate objects: 30
# Number of self standing objects: 26
# Processing 88EM87C_000013_mito.pkl
# Number of masks: 26
# Number of separate objects: 22
# Number of self standing objects: 21
# Processing 88EM87C_000014_mito.pkl
# Number of masks: 27
# Number of separate objects: 19
# Number of self standing objects: 18
# Processing 88EM87C_000015_mito.pkl
# Number of masks: 39
# Number of separate objects: 31
# Number of self standing objects: 28
# Processing 88EM87C_000016_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000017_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000018_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000019_mito.pkl
# Number of masks: 21
# Number of separate objects: 20
# Number of self standing objects: 17
# Processing 88EM87C_000020_mito.pkl
# Number of masks: 24
# Number of separate objects: 20
# Number of self standing objects: 16
# Processing 88EM87C_000021_mito.pkl
# Number of masks: 13
# Number of separate objects: 11
# Number of self standing objects: 9
# Processing 88EM87C_000022_mito.pkl
# Number of masks: 17
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000023_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000024_mito.pkl
# Number of masks: 20
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000025_mito.pkl
# Number of masks: 7
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000026_mito.pkl
# Number of masks: 18
# Number of separate objects: 18
# Number of self standing objects: 16
# Processing 88EM87C_000027_mito.pkl
# Number of masks: 16
# Number of separate objects: 16
# Number of self standing objects: 14
# Processing 88EM87C_000028_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000029_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000030_mito.pkl
# Number of masks: 7
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000031_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000032_mito.pkl
# Number of masks: 13
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000033_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000034_mito.pkl
# Number of masks: 9
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000035_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000036_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000037_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000038_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000039_mito.pkl
# Number of masks: 12
# Number of separate objects: 9
# Number of self standing objects: 7
# Processing 88EM87C_000040_mito.pkl
# Number of masks: 16
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000041_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000042_mito.pkl
# Number of masks: 17
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000043_mito.pkl
# Number of masks: 14
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000044_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000045_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000046_mito.pkl
# Number of masks: 29
# Number of separate objects: 19
# Number of self standing objects: 19
# Processing 88EM87C_000047_mito.pkl
# Number of masks: 22
# Number of separate objects: 19
# Number of self standing objects: 19
# Processing 88EM87C_000048_mito.pkl
# Number of masks: 14
# Number of separate objects: 13
# Number of self standing objects: 13
# Processing 88EM87C_000049_mito.pkl
# Number of masks: 26
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000050_mito.pkl
# Number of masks: 14
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000051_mito.pkl
# Number of masks: 15
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000052_mito.pkl
# Number of masks: 21
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000053_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000054_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 15
# Processing 88EM87C_000055_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000056_mito.pkl
# Number of masks: 22
# Number of separate objects: 20
# Number of self standing objects: 20
# Processing 88EM87C_000057_mito.pkl
# Number of masks: 20
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000058_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000059_mito.pkl
# Number of masks: 14
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000060_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000061_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000062_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000063_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000064_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000065_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000066_mito.pkl
# Number of masks: 4
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000067_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000068_mito.pkl
# Number of masks: 8
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000069_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000070_mito.pkl
# Number of masks: 35
# Number of separate objects: 23
# Number of self standing objects: 23
# Processing 88EM87C_000071_mito.pkl
# Number of masks: 8
# Number of separate objects: 8
# Number of self standing objects: 6
# Processing 88EM87C_000072_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000073_mito.pkl
# Number of masks: 27
# Number of separate objects: 20
# Number of self standing objects: 19
# Processing 88EM87C_000074_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000075_mito.pkl
# Number of masks: 22
# Number of separate objects: 18
# Number of self standing objects: 16
# Processing 88EM87C_000076_mito.pkl
# Number of masks: 15
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000077_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000078_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000079_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000080_mito.pkl
# Number of masks: 16
# Number of separate objects: 13
# Number of self standing objects: 12
# Processing 88EM87C_000081_mito.pkl
# Number of masks: 32
# Number of separate objects: 29
# Number of self standing objects: 27
# Processing 88EM87C_000082_mito.pkl
# Number of masks: 18
# Number of separate objects: 13
# Number of self standing objects: 13
# Processing 88EM87C_000083_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000084_mito.pkl
# Number of masks: 8
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000085_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000086_mito.pkl
# Number of masks: 3
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000087_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000088_mito.pkl
# Number of masks: 16
# Number of separate objects: 13
# Number of self standing objects: 10
# Processing 88EM87C_000089_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000090_mito.pkl
# Number of masks: 11
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000091_mito.pkl
# Number of masks: 19
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000092_mito.pkl
# Number of masks: 28
# Number of separate objects: 24
# Number of self standing objects: 22
# Processing 88EM87C_000093_mito.pkl
# Number of masks: 13
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000094_mito.pkl
# Number of masks: 35
# Number of separate objects: 30
# Number of self standing objects: 27
# Processing 88EM87C_000095_mito.pkl
# Number of masks: 16
# Number of separate objects: 13
# Number of self standing objects: 12
# Processing 88EM87C_000096_mito.pkl
# Number of masks: 17
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000097_mito.pkl
# Number of masks: 5
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000098_mito.pkl
# Number of masks: 29
# Number of separate objects: 28
# Number of self standing objects: 26
# Processing 88EM87C_000099_mito.pkl
# Number of masks: 25
# Number of separate objects: 20
# Number of self standing objects: 19
# Processing 88EM87C_000100_mito.pkl
# Number of masks: 16
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000101_mito.pkl
# Number of masks: 13
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000102_mito.pkl
# Number of masks: 10
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000103_mito.pkl
# Number of masks: 10
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000104_mito.pkl
# Number of masks: 31
# Number of separate objects: 23
# Number of self standing objects: 21
# Processing 88EM87C_000105_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000106_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000107_mito.pkl
# Number of masks: 29
# Number of separate objects: 21
# Number of self standing objects: 18
# Processing 88EM87C_000108_mito.pkl
# Number of masks: 18
# Number of separate objects: 16
# Number of self standing objects: 13
# Processing 88EM87C_000109_mito.pkl
# Number of masks: 27
# Number of separate objects: 22
# Number of self standing objects: 21
# Processing 88EM87C_000110_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 4
# Processing 88EM87C_000111_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000112_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000113_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000114_mito.pkl
# Number of masks: 8
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000115_mito.pkl
# Number of masks: 25
# Number of separate objects: 20
# Number of self standing objects: 18
# Processing 88EM87C_000116_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000117_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000118_mito.pkl
# Number of masks: 9
# Number of separate objects: 7
# Number of self standing objects: 7
# Processing 88EM87C_000119_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000120_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000121_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000122_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000123_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000124_mito.pkl
# Number of masks: 40
# Number of separate objects: 33
# Number of self standing objects: 30
# Processing 88EM87C_000125_mito.pkl
# Number of masks: 27
# Number of separate objects: 23
# Number of self standing objects: 22
# Processing 88EM87C_000126_mito.pkl
# Number of masks: 19
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000127_mito.pkl
# Number of masks: 16
# Number of separate objects: 10
# Number of self standing objects: 7
# Processing 88EM87C_000128_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000129_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000130_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000131_mito.pkl
# Number of masks: 7
# Number of separate objects: 7
# Number of self standing objects: 4
# Processing 88EM87C_000132_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000133_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000134_mito.pkl
# Number of masks: 22
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000135_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000136_mito.pkl
# Number of masks: 25
# Number of separate objects: 20
# Number of self standing objects: 20
# Processing 88EM87C_000137_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000138_mito.pkl
# Number of masks: 25
# Number of separate objects: 21
# Number of self standing objects: 20
# Processing 88EM87C_000139_mito.pkl
# Number of masks: 32
# Number of separate objects: 19
# Number of self standing objects: 17
# Processing 88EM87C_000140_mito.pkl
# Number of masks: 21
# Number of separate objects: 16
# Number of self standing objects: 14
# Processing 88EM87C_000141_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000142_mito.pkl
# Number of masks: 8
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000143_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 7
# Processing 88EM87C_000144_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 4
# Processing 88EM87C_000145_mito.pkl
# Number of masks: 13
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000146_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000147_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000148_mito.pkl
# Number of masks: 14
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000149_mito.pkl
# Number of masks: 27
# Number of separate objects: 17
# Number of self standing objects: 16
# Processing 88EM87C_000150_mito.pkl
# Number of masks: 16
# Number of separate objects: 14
# Number of self standing objects: 12
# Processing 88EM87C_000151_mito.pkl
# Number of masks: 14
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000152_mito.pkl
# Number of masks: 10
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000153_mito.pkl
# Number of masks: 12
# Number of separate objects: 9
# Number of self standing objects: 6
# Processing 88EM87C_000154_mito.pkl
# Number of masks: 18
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000155_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000156_mito.pkl
# Number of masks: 20
# Number of separate objects: 19
# Number of self standing objects: 17
# Processing 88EM87C_000157_mito.pkl
# Number of masks: 25
# Number of separate objects: 23
# Number of self standing objects: 23
# Processing 88EM87C_000158_mito.pkl
# Number of masks: 38
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000159_mito.pkl
# Number of masks: 15
# Number of separate objects: 14
# Number of self standing objects: 12
# Processing 88EM87C_000160_mito.pkl
# Number of masks: 25
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000161_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000162_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000163_mito.pkl
# Number of masks: 16
# Number of separate objects: 12
# Number of self standing objects: 10
# Processing 88EM87C_000164_mito.pkl
# Number of masks: 18
# Number of separate objects: 18
# Number of self standing objects: 15
# Processing 88EM87C_000165_mito.pkl
# Number of masks: 12
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000166_mito.pkl
# Number of masks: 8
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000167_mito.pkl
# Number of masks: 13
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000168_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000169_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 8
# Processing 88EM87C_000170_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000171_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000172_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000173_mito.pkl
# Number of masks: 21
# Number of separate objects: 20
# Number of self standing objects: 19
# Processing 88EM87C_000174_mito.pkl
# Number of masks: 15
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000175_mito.pkl
# Number of masks: 15
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000176_mito.pkl
# Number of masks: 7
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000177_mito.pkl
# Number of masks: 38
# Number of separate objects: 25
# Number of self standing objects: 24
# Processing 88EM87C_000178_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000179_mito.pkl
# Number of masks: 14
# Number of separate objects: 14
# Number of self standing objects: 13
# Processing 88EM87C_000180_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000181_mito.pkl
# Number of masks: 28
# Number of separate objects: 23
# Number of self standing objects: 22
# Processing 88EM87C_000182_mito.pkl
# Number of masks: 11
# Number of separate objects: 11
# Number of self standing objects: 9
# Processing 88EM87C_000183_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000184_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000185_mito.pkl
# Number of masks: 3
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000186_mito.pkl
# Number of masks: 7
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000187_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000188_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000189_mito.pkl
# Number of masks: 19
# Number of separate objects: 16
# Number of self standing objects: 13
# Processing 88EM87C_000190_mito.pkl
# Number of masks: 21
# Number of separate objects: 18
# Number of self standing objects: 15
# Processing 88EM87C_000191_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000192_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000193_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000194_mito.pkl
# Number of masks: 19
# Number of separate objects: 19
# Number of self standing objects: 16
# Processing 88EM87C_000195_mito.pkl
# Number of masks: 7
# Number of separate objects: 7
# Number of self standing objects: 7
# Processing 88EM87C_000196_mito.pkl
# Number of masks: 17
# Number of separate objects: 16
# Number of self standing objects: 16
# Processing 88EM87C_000197_mito.pkl
# Number of masks: 16
# Number of separate objects: 14
# Number of self standing objects: 12
# Processing 88EM87C_000198_mito.pkl
# Number of masks: 6
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000199_mito.pkl
# Number of masks: 17
# Number of separate objects: 13
# Number of self standing objects: 13
# Processing 88EM87C_000200_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000201_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000202_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 4
# Processing 88EM87C_000203_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000204_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000205_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 15
# Processing 88EM87C_000206_mito.pkl
# Number of masks: 1
# Number of separate objects: 0
# Number of self standing objects: 0
# Processing 88EM87C_000207_mito.pkl
# Number of masks: 39
# Number of separate objects: 37
# Number of self standing objects: 34
# Processing 88EM87C_000208_mito.pkl
# Number of masks: 10
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000209_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 1
# Processing 88EM87C_000210_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000211_mito.pkl
# Number of masks: 26
# Number of separate objects: 21
# Number of self standing objects: 20
# Processing 88EM87C_000212_mito.pkl
# Number of masks: 10
# Number of separate objects: 9
# Number of self standing objects: 7
# Processing 88EM87C_000213_mito.pkl
# Number of masks: 12
# Number of separate objects: 12
# Number of self standing objects: 10
# Processing 88EM87C_000214_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000215_mito.pkl
# Number of masks: 18
# Number of separate objects: 18
# Number of self standing objects: 16
# Processing 88EM87C_000216_mito.pkl
# Number of masks: 12
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000217_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000218_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000219_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000220_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000221_mito.pkl
# Number of masks: 20
# Number of separate objects: 14
# Number of self standing objects: 13
# Processing 88EM87C_000222_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000223_mito.pkl
# Number of masks: 34
# Number of separate objects: 29
# Number of self standing objects: 26
# Processing 88EM87C_000224_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000225_mito.pkl
# Number of masks: 40
# Number of separate objects: 38
# Number of self standing objects: 36
# Processing 88EM87C_000226_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000227_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000228_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000229_mito.pkl
# Number of masks: 31
# Number of separate objects: 23
# Number of self standing objects: 20
# Processing 88EM87C_000230_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000231_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000232_mito.pkl
# Number of masks: 12
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000233_mito.pkl
# Number of masks: 9
# Number of separate objects: 7
# Number of self standing objects: 7
# Processing 88EM87C_000234_mito.pkl
# Number of masks: 19
# Number of separate objects: 17
# Number of self standing objects: 15
# Processing 88EM87C_000235_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000236_mito.pkl
# Number of masks: 18
# Number of separate objects: 17
# Number of self standing objects: 14
# Processing 88EM87C_000237_mito.pkl
# Number of masks: 25
# Number of separate objects: 21
# Number of self standing objects: 18
# Processing 88EM87C_000238_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000239_mito.pkl
# Number of masks: 10
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000240_mito.pkl
# Number of masks: 28
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000241_mito.pkl
# Number of masks: 26
# Number of separate objects: 20
# Number of self standing objects: 16
# Processing 88EM87C_000242_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000243_mito.pkl
# Number of masks: 15
# Number of separate objects: 13
# Number of self standing objects: 10
# Processing 88EM87C_000244_mito.pkl
# Number of masks: 27
# Number of separate objects: 24
# Number of self standing objects: 22
# Processing 88EM87C_000245_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000246_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000247_mito.pkl
# Number of masks: 8
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000248_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000249_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000250_mito.pkl
# Number of masks: 15
# Number of separate objects: 14
# Number of self standing objects: 13
# Processing 88EM87C_000251_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000252_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000253_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000254_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000255_mito.pkl
# Number of masks: 20
# Number of separate objects: 18
# Number of self standing objects: 16
# Processing 88EM87C_000256_mito.pkl
# Number of masks: 14
# Number of separate objects: 14
# Number of self standing objects: 10
# Processing 88EM87C_000257_mito.pkl
# Number of masks: 7
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000258_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000259_mito.pkl
# Number of masks: 11
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000260_mito.pkl
# Number of masks: 10
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000261_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000262_mito.pkl
# Number of masks: 16
# Number of separate objects: 13
# Number of self standing objects: 13
# Processing 88EM87C_000263_mito.pkl
# Number of masks: 19
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000264_mito.pkl
# Number of masks: 23
# Number of separate objects: 20
# Number of self standing objects: 18
# Processing 88EM87C_000265_mito.pkl
# Number of masks: 15
# Number of separate objects: 12
# Number of self standing objects: 12
# Processing 88EM87C_000266_mito.pkl
# Number of masks: 14
# Number of separate objects: 14
# Number of self standing objects: 13
# Processing 88EM87C_000267_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000268_mito.pkl
# Number of masks: 16
# Number of separate objects: 14
# Number of self standing objects: 11
# Processing 88EM87C_000269_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000270_mito.pkl
# Number of masks: 13
# Number of separate objects: 10
# Number of self standing objects: 8
# Processing 88EM87C_000271_mito.pkl
# Number of masks: 18
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000272_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000273_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 12
# Processing 88EM87C_000274_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000275_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000276_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000277_mito.pkl
# Number of masks: 14
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000278_mito.pkl
# Number of masks: 15
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000279_mito.pkl
# Number of masks: 5
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000280_mito.pkl
# Number of masks: 21
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000281_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000282_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000283_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000284_mito.pkl
# Number of masks: 7
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000285_mito.pkl
# Number of masks: 15
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000286_mito.pkl
# Number of masks: 15
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000287_mito.pkl
# Number of masks: 22
# Number of separate objects: 18
# Number of self standing objects: 15
# Processing 88EM87C_000288_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000289_mito.pkl
# Number of masks: 16
# Number of separate objects: 13
# Number of self standing objects: 13
# Processing 88EM87C_000290_mito.pkl
# Number of masks: 19
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000291_mito.pkl
# Number of masks: 11
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000292_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000293_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000294_mito.pkl
# Number of masks: 11
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000295_mito.pkl
# Number of masks: 22
# Number of separate objects: 18
# Number of self standing objects: 18
# Processing 88EM87C_000296_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000297_mito.pkl
# Number of masks: 7
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000298_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000299_mito.pkl
# Number of masks: 24
# Number of separate objects: 17
# Number of self standing objects: 17
# Processing 88EM87C_000300_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000301_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000302_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000303_mito.pkl
# Number of masks: 12
# Number of separate objects: 12
# Number of self standing objects: 10
# Processing 88EM87C_000304_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000305_mito.pkl
# Number of masks: 5
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000306_mito.pkl
# Number of masks: 10
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000307_mito.pkl
# Number of masks: 10
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000308_mito.pkl
# Number of masks: 14
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000309_mito.pkl
# Number of masks: 11
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000310_mito.pkl
# Number of masks: 17
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000311_mito.pkl
# Number of masks: 7
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000312_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000313_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000314_mito.pkl
# Number of masks: 22
# Number of separate objects: 19
# Number of self standing objects: 16
# Processing 88EM87C_000315_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000316_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000317_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000318_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000319_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000320_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000321_mito.pkl
# Number of masks: 4
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000322_mito.pkl
# Number of masks: 17
# Number of separate objects: 15
# Number of self standing objects: 13
# Processing 88EM87C_000323_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000324_mito.pkl
# Number of masks: 21
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000325_mito.pkl
# Number of masks: 15
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000326_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000327_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000328_mito.pkl
# Number of masks: 29
# Number of separate objects: 25
# Number of self standing objects: 22
# Processing 88EM87C_000329_mito.pkl
# No masks found
# Processing 88EM87C_000330_mito.pkl
# Number of masks: 28
# Number of separate objects: 24
# Number of self standing objects: 21
# Processing 88EM87C_000331_mito.pkl
# Number of masks: 14
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000332_mito.pkl
# Number of masks: 16
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000333_mito.pkl
# Number of masks: 17
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000334_mito.pkl
# Number of masks: 4
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000335_mito.pkl
# Number of masks: 19
# Number of separate objects: 16
# Number of self standing objects: 16
# Processing 88EM87C_000336_mito.pkl
# Number of masks: 16
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000337_mito.pkl
# Number of masks: 10
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000338_mito.pkl
# Number of masks: 10
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000339_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000340_mito.pkl
# Number of masks: 24
# Number of separate objects: 21
# Number of self standing objects: 18
# Processing 88EM87C_000341_mito.pkl
# Number of masks: 15
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000342_mito.pkl
# Number of masks: 19
# Number of separate objects: 17
# Number of self standing objects: 16
# Processing 88EM87C_000343_mito.pkl
# Number of masks: 18
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000344_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000345_mito.pkl
# Number of masks: 14
# Number of separate objects: 14
# Number of self standing objects: 11
# Processing 88EM87C_000346_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000347_mito.pkl
# Number of masks: 16
# Number of separate objects: 15
# Number of self standing objects: 11
# Processing 88EM87C_000348_mito.pkl
# Number of masks: 8
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000349_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000350_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000351_mito.pkl
# Number of masks: 12
# Number of separate objects: 12
# Number of self standing objects: 10
# Processing 88EM87C_000352_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000353_mito.pkl
# Number of masks: 12
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000354_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000355_mito.pkl
# Number of masks: 18
# Number of separate objects: 17
# Number of self standing objects: 16
# Processing 88EM87C_000356_mito.pkl
# Number of masks: 11
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000357_mito.pkl
# Number of masks: 10
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000358_mito.pkl
# Number of masks: 19
# Number of separate objects: 16
# Number of self standing objects: 16
# Processing 88EM87C_000359_mito.pkl
# Number of masks: 14
# Number of separate objects: 11
# Number of self standing objects: 8
# Processing 88EM87C_000360_mito.pkl
# Number of masks: 16
# Number of separate objects: 15
# Number of self standing objects: 12
# Processing 88EM87C_000361_mito.pkl
# Number of masks: 11
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000362_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000363_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000364_mito.pkl
# Number of masks: 11
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000365_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000366_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000367_mito.pkl
# Number of masks: 30
# Number of separate objects: 25
# Number of self standing objects: 22
# Processing 88EM87C_000368_mito.pkl
# Number of masks: 8
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000369_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000370_mito.pkl
# Number of masks: 11
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000371_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000372_mito.pkl
# Number of masks: 13
# Number of separate objects: 11
# Number of self standing objects: 9
# Processing 88EM87C_000373_mito.pkl
# Number of masks: 18
# Number of separate objects: 14
# Number of self standing objects: 14
# Processing 88EM87C_000374_mito.pkl
# Number of masks: 27
# Number of separate objects: 19
# Number of self standing objects: 18
# Processing 88EM87C_000375_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000376_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000377_mito.pkl
# Number of masks: 18
# Number of separate objects: 15
# Number of self standing objects: 15
# Processing 88EM87C_000378_mito.pkl
# Number of masks: 29
# Number of separate objects: 26
# Number of self standing objects: 23
# Processing 88EM87C_000379_mito.pkl
# Number of masks: 17
# Number of separate objects: 13
# Number of self standing objects: 12
# Processing 88EM87C_000380_mito.pkl
# Number of masks: 11
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000381_mito.pkl
# Number of masks: 40
# Number of separate objects: 37
# Number of self standing objects: 28
# Processing 88EM87C_000382_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000383_mito.pkl
# Number of masks: 7
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000384_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000385_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000386_mito.pkl
# Number of masks: 13
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000387_mito.pkl
# Number of masks: 10
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000388_mito.pkl
# Number of masks: 14
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000389_mito.pkl
# Number of masks: 9
# Number of separate objects: 7
# Number of self standing objects: 7
# Processing 88EM87C_000390_mito.pkl
# Number of masks: 15
# Number of separate objects: 13
# Number of self standing objects: 11
# Processing 88EM87C_000391_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000392_mito.pkl
# Number of masks: 11
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000393_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000394_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000395_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000396_mito.pkl
# Number of masks: 21
# Number of separate objects: 14
# Number of self standing objects: 13
# Processing 88EM87C_000397_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000398_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000399_mito.pkl
# Number of masks: 19
# Number of separate objects: 17
# Number of self standing objects: 14
# Processing 88EM87C_000400_mito.pkl
# Number of masks: 3
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000401_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000402_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 7
# Processing 88EM87C_000403_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000404_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000405_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000406_mito.pkl
# Number of masks: 10
# Number of separate objects: 8
# Number of self standing objects: 6
# Processing 88EM87C_000407_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000408_mito.pkl
# Number of masks: 12
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000409_mito.pkl
# Number of masks: 9
# ...
# Number of self standing objects: 5
# Processing 88EM87C_000414_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000415_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000416_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000417_mito.pkl
# Number of masks: 8
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000418_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000419_mito.pkl
# Number of masks: 13
# Number of separate objects: 10
# Number of self standing objects: 8
# Processing 88EM87C_000420_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000421_mito.pkl
# Number of masks: 1
# Number of separate objects: 0
# Number of self standing objects: 0
# Processing 88EM87C_000422_mito.pkl
# Number of masks: 7
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000423_mito.pkl
# Number of masks: 9
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000424_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000425_mito.pkl
# Number of masks: 17
# Number of separate objects: 15
# Number of self standing objects: 14
# Processing 88EM87C_000426_mito.pkl
# Number of masks: 6
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000427_mito.pkl
# Number of masks: 10
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000428_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000429_mito.pkl
# Number of masks: 4
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000430_mito.pkl
# Number of masks: 13
# Number of separate objects: 12
# Number of self standing objects: 10
# Processing 88EM87C_000431_mito.pkl
# Number of masks: 10
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000432_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000433_mito.pkl
# Number of masks: 7
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000434_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000435_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000436_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000437_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 1
# Processing 88EM87C_000438_mito.pkl
# Number of masks: 10
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000439_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 4
# Processing 88EM87C_000440_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000441_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000442_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000443_mito.pkl
# Number of masks: 23
# Number of separate objects: 19
# Number of self standing objects: 17
# Processing 88EM87C_000444_mito.pkl
# Number of masks: 13
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000445_mito.pkl
# Number of masks: 39
# Number of separate objects: 30
# Number of self standing objects: 30
# Processing 88EM87C_000446_mito.pkl
# Number of masks: 8
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000447_mito.pkl
# Number of masks: 7
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000448_mito.pkl
# Number of masks: 2
# Number of separate objects: 0
# Number of self standing objects: 0
# Processing 88EM87C_000449_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000450_mito.pkl
# Number of masks: 7
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000451_mito.pkl
# Number of masks: 18
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000452_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 6
# Processing 88EM87C_000453_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 12
# Processing 88EM87C_000454_mito.pkl
# Number of masks: 10
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000455_mito.pkl
# Number of masks: 21
# Number of separate objects: 14
# Number of self standing objects: 9
# Processing 88EM87C_000456_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000457_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000458_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 12
# Processing 88EM87C_000459_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000460_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000461_mito.pkl
# Number of masks: 7
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000462_mito.pkl
# Number of masks: 9
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000463_mito.pkl
# Number of masks: 15
# Number of separate objects: 12
# Number of self standing objects: 9
# Processing 88EM87C_000464_mito.pkl
# Number of masks: 13
# Number of separate objects: 8
# Number of self standing objects: 8
# Processing 88EM87C_000465_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 9
# Processing 88EM87C_000466_mito.pkl
# Number of masks: 3
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000467_mito.pkl
# Number of masks: 4
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000468_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000469_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000470_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000471_mito.pkl
# Number of masks: 7
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000472_mito.pkl
# Number of masks: 17
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000473_mito.pkl
# Number of masks: 3
# Number of separate objects: 3
# Number of self standing objects: 2
# Processing 88EM87C_000474_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000475_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000476_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 2
# Processing 88EM87C_000477_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000478_mito.pkl
# Number of masks: 7
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000479_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000480_mito.pkl
# Number of masks: 18
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000481_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000482_mito.pkl
# Number of masks: 15
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000483_mito.pkl
# Number of masks: 10
# Number of separate objects: 10
# Number of self standing objects: 10
# Processing 88EM87C_000484_mito.pkl
# Number of masks: 16
# Number of separate objects: 11
# Number of self standing objects: 10
# Processing 88EM87C_000485_mito.pkl
# Number of masks: 15
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000486_mito.pkl
# Number of masks: 7
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000487_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000488_mito.pkl
# Number of masks: 9
# Number of separate objects: 8
# Number of self standing objects: 7
# Processing 88EM87C_000489_mito.pkl
# Number of masks: 21
# Number of separate objects: 17
# Number of self standing objects: 16
# Processing 88EM87C_000490_mito.pkl
# Number of masks: 15
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000491_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000492_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000493_mito.pkl
# Number of masks: 13
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000494_mito.pkl
# Number of masks: 8
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000495_mito.pkl
# Number of masks: 9
# Number of separate objects: 9
# Number of self standing objects: 8
# Processing 88EM87C_000496_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000497_mito.pkl
# Number of masks: 5
# Number of separate objects: 4
# Number of self standing objects: 2
# Processing 88EM87C_000498_mito.pkl
# Number of masks: 0
# No masks found
# Processing 88EM87C_000499_mito.pkl
# Number of masks: 29
# Number of separate objects: 27
# Number of self standing objects: 22
# Processing 88EM87C_000500_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000501_mito.pkl
# Number of masks: 6
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000502_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000503_mito.pkl
# Number of masks: 12
# Number of separate objects: 10
# Number of self standing objects: 9
# Processing 88EM87C_000504_mito.pkl
# Number of masks: 17
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000505_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 5
# Processing 88EM87C_000506_mito.pkl
# Number of masks: 13
# Number of separate objects: 9
# Number of self standing objects: 7
# Processing 88EM87C_000507_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000508_mito.pkl
# Number of masks: 10
# Number of separate objects: 9
# Number of self standing objects: 7
# Processing 88EM87C_000509_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 1
# Processing 88EM87C_000510_mito.pkl
# Number of masks: 39
# Number of separate objects: 34
# Number of self standing objects: 28
# Processing 88EM87C_000511_mito.pkl
# Number of masks: 20
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000512_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 9
# Processing 88EM87C_000513_mito.pkl
# Number of masks: 28
# Number of separate objects: 20
# Number of self standing objects: 17
# Processing 88EM87C_000514_mito.pkl
# Number of masks: 12
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000515_mito.pkl
# Number of masks: 13
# Number of separate objects: 12
# Number of self standing objects: 9
# Processing 88EM87C_000516_mito.pkl
# Number of masks: 14
# Number of separate objects: 13
# Number of self standing objects: 12
# Processing 88EM87C_000517_mito.pkl
# Number of masks: 6
# Number of separate objects: 4
# Number of self standing objects: 4
# Processing 88EM87C_000518_mito.pkl
# Number of masks: 6
# Number of separate objects: 6
# Number of self standing objects: 5
# Processing 88EM87C_000519_mito.pkl
# Number of masks: 2
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000520_mito.pkl
# Number of masks: 19
# Number of separate objects: 17
# Number of self standing objects: 15
# Processing 88EM87C_000521_mito.pkl
# Number of masks: 28
# Number of separate objects: 25
# Number of self standing objects: 21
# Processing 88EM87C_000522_mito.pkl
# Number of masks: 4
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000523_mito.pkl
# Number of masks: 3
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000524_mito.pkl
# Number of masks: 9
# Number of separate objects: 7
# Number of self standing objects: 5
# Processing 88EM87C_000525_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000526_mito.pkl
# Number of masks: 3
# Number of separate objects: 2
# Number of self standing objects: 1
# Processing 88EM87C_000527_mito.pkl
# Number of masks: 5
# Number of separate objects: 3
# Number of self standing objects: 3
# Processing 88EM87C_000528_mito.pkl
# Number of masks: 20
# Number of separate objects: 17
# Number of self standing objects: 16
# Processing 88EM87C_000529_mito.pkl
# Number of masks: 30
# Number of separate objects: 22
# Number of self standing objects: 15
# Processing 88EM87C_000530_mito.pkl
# Number of masks: 6
# Number of separate objects: 4
# Number of self standing objects: 3
# Processing 88EM87C_000531_mito.pkl
# Number of masks: 8
# Number of separate objects: 7
# Number of self standing objects: 6
# Processing 88EM87C_000532_mito.pkl
# Number of masks: 33
# Number of separate objects: 26
# Number of self standing objects: 24
# Processing 88EM87C_000533_mito.pkl
# Number of masks: 9
# Number of separate objects: 8
# Number of self standing objects: 6
# Processing 88EM87C_000534_mito.pkl
# Number of masks: 38
# Number of separate objects: 32
# Number of self standing objects: 29
# Processing 88EM87C_000535_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 1
# Processing 88EM87C_000536_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000537_mito.pkl
# Number of masks: 14
# Number of separate objects: 11
# Number of self standing objects: 9
# Processing 88EM87C_000538_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000539_mito.pkl
# Number of masks: 1
# Number of separate objects: 0
# Number of self standing objects: 0
# Processing 88EM87C_000540_mito.pkl
# Number of masks: 1
# Number of separate objects: 1
# Number of self standing objects: 1
# Processing 88EM87C_000541_mito.pkl
# Number of masks: 17
# Number of separate objects: 16
# Number of self standing objects: 15
# Processing 88EM87C_000542_mito.pkl
# Number of masks: 5
# Number of separate objects: 5
# Number of self standing objects: 4
# Processing 88EM87C_000543_mito.pkl
# Number of masks: 21
# Number of separate objects: 15
# Number of self standing objects: 12
# Processing 88EM87C_000544_mito.pkl
# Number of masks: 2
# Number of separate objects: 2
# Number of self standing objects: 2
# Processing 88EM87C_000545_mito.pkl
# Number of masks: 21
# Number of separate objects: 11
# Number of self standing objects: 11
# Processing 88EM87C_000546_mito.pkl
# Number of masks: 14
# Number of separate objects: 12
# Number of self standing objects: 11
# Processing 88EM87C_000547_mito.pkl
# Number of masks: 9
# Number of separate objects: 6
# Number of self standing objects: 6
# Processing 88EM87C_000548_mito.pkl
# Number of masks: 17
# Number of separate objects: 12
# Number of self standing objects: 11

# %% [markdown]
# ## Classify objects

# %%
learn = load_learner(classifier_path)
learn.model.cuda()
print(next(learn.model.parameters()).device)  # Should print 'cuda:0'
# Out:
# /home/kasia/miniforge3/envs/fastai-env/lib/python3.11/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# cuda:0

# %%
pad = 50

df_mitos['prediction_prob'] = None
df_mitos['prediction_prob'] = df_mitos['prediction_prob'].astype(object)

for ind, row in tqdm(df_mitos.iterrows(), total=len(df_mitos)):

    row_start = int(row['centroid-0'] - pad)
    row_stop = int(row['centroid-0'] + pad)
    col_start = int(row['centroid-1'] - pad)
    col_stop = int(row['centroid-1'] + pad)

    im_mito = gray2rgb(im[row_start:row_stop, col_start:col_stop]).compute()

    cat,_,probs = learn.predict(im_mito)
    df_mitos.loc[ind,'prediction'] = str(cat)
    df_mitos.at[ind,'prediction_prob'] = np.array(probs, dtype=float) 

    df_mitos['prediction_prob'] = df_mitos['prediction_prob'].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)

# save the data frame
df_name = f'{prefix_save}mitos.pkl'
df_mitos.to_pickle(os.path.join(output_dir,df_name))
